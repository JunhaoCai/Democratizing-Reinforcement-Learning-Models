# %%
from __future__ import unicode_literals, print_function, division
from io import open
from SVM_DataProcess import prepare_data, build_word2vec
from SVM_Config import Config

splist = []
# 构建word2id词典
word2id = {}
with open(Config.word2id_path, encoding='utf-8') as f:
    for line in f.readlines():
        sp = line.strip().split()  # 去掉\n \t 等
        splist.append(sp)
    word2id = dict(splist)  # 转成字典

# 转换索引的数据类型为整数
for key in word2id:
    word2id[key] = int(word2id[key])

# 构建id2word
id2word = {}
for key, val in word2id.items():
    id2word[val] = key

# 构建word2vec词向量
w2vec = build_word2vec(Config.pre_word2vec_path, word2id, None)

print("id2word.shape", id2word)
print("w2Vec.shape: ", w2vec.shape) # w2Vec.shape:  (54848, 50)

# 得到数字索引表示的句子和标签
train_array, train_lable, val_array, val_lable, test_array, test_lable = prepare_data(word2id,
                                                                                      train_path=Config.train_path,
                                                                                      val_path=Config.val_path,
                                                                                      test_path=Config.test_path,
                                                                                      seq_lenth=Config.max_sen_len)

print("train_array.shape", train_array.shape)
print("test_array.shape", test_array.shape)
train_lable = train_lable.ravel()
val_lable = val_lable.ravel()
test_lable = test_lable.ravel()
# Out:
# id2word.shape {0: '_PAD_', 1: '死囚', 2: '爱', 3: '刽子手', 4: '女贼', 5: '衙役', 6: '我们', 7: '你们', 8: '难道', 9: '还有', 10: '别的', 11: '选择', 12: '没想到', 13: '胡军', 14: '除了', 15: '蓝宇', 16: '东宫', 17: '西宫', 18: '我', 19: '个', 20: '去', 21: '阿兰', 22: '这样', 23: '真', 24: '他', 25: '恶心', 26: '爱个', 27: '分明', 28: '只是', 29: '欲', 30: '其实', 31: '对', 32: '锦衣卫', 33: '爱情', 34: '很萌', 35: '因为', 36: '很', 37: '言情小说', 38: '可惜', 39: '女主角', 40: '我要', 41: '不是', 42: '被', 43: '乔花', 44: '偷', 45: '令牌', 46: '青龙', 47: '吃醋', 48: '想出', 49: '箭', 50: '那里', 51: '萌到', 52: '让', 53: '想起', 54: '雏菊', 55: '里', 56: '郑', 57: '大叔', 58: '徐子珊', 59: '吴尊', 60: '真是', 61: '可怕', 62: '他们', 63: '完全', 64: '电影', 65: '料', 66: '脱脱', 67: '这个', 68: '名字', 69: '想要', 70: '雷死', 71: '观众', 72: '导演', 73: '到底', 74: '想', 75: '什么', 76: '剧情', 77: '混乱', 78: '老套', 79: '无趣', 80: '对白', 81: '更是', 82: '白痴', 83: '失望', 84: '两星', 85: '半', 86: '小', 87: '明星', 88: '本色', 89: '出演', 90: '老', 91: '演员', 92: '自己', 93: '发挥', 94: '基本上', 95: '王力宏', 96: '表演', 97: '指导', 98: '上', 99: '没有', 100: '可', 101: '地方', 102: '整体', 103: '结构', 104: '失衡', 105: '情节', 106: '讨巧', 107: '也', 108: '一众', 109: '喜欢', 110: '原因', 111: '使得', 112: '这部', 113: '演唱会', 114: '一样', 115: '不停', 116: '处女作', 117: '却', 118: '体现', 119: '不', 120: '出', 121: '个人', 122: '风格', 123: '不能', 124: '说', 125: '成功', 126: '相对来说', 127: '周董', 128: '更', 129: '像', 130: '一些', 131: '神马', 132: '狗血', 133: '编剧', 134: '垃圾', 135: '女', 136: '猪脚', 137: '无', 138: '胸无', 139: '人', 140: '胃口', 141: '一干', 142: '男', 143: '基情', 144: '四射', 145: '毫无', 146: '演技', 147: '虽然', 148: '很多', 149: '比', 150: '你', 151: '烂', 152: '但', 153: '掌握', 154: '这么', 155: '多', 156: '资源', 157: '拍成', 158: '给', 159: '丫', 160: '一颗', 161: '星', 162: '胸闷', 163: '半顆', 164: '我們', 165: '家', 166: '說', 167: '這是', 168: '一部', 169: '從', 170: '開始', 171: '第十二', 172: '分鐘', 173: '打哈欠', 174: '一直', 175: '最', 176: '後', 177: '迫不及待', 178: '離場', 179: '商業', 180: '氣息', 181: '無比', 182: '濃重', 183: '看不得', 184: '植入', 185: '廣告', 186: '三秒', 187: '狗屎', 188: '大好河山', 189: '背景', 190: '電影', 191: '順便', 192: '坐', 193: '前面', 194: '落寞', 195: '合著', 196: '鬍', 197: '水', 198: '留下', 199: '深刻印象', 200: '明白', 201: '為', 202: '觀眾', 203: '如此', 204: '配合', 205: '这种', 206: '忒', 207: '著名', 208: '历史', 209: '事件', 210: '严谨', 211: '尊重', 212: '一点', 213: '预计', 214: '撒', 215: '自刎', 216: '乌江', 217: '四面楚歌', 218: '细节', 219: '太', 220: '还原', 221: '实属', 222: '主要', 223: '角色', 224: '刘邦', 225: '项羽', 226: '性格', 227: '塑造', 228: '失败', 229: '陈小春', 230: '饰演', 231: '樊哙', 232: '算', 233: '鲜明', 234: '黎明', 235: '上不起', 236: '不想', 237: '评论', 238: '直接', 239: '败坏', 240: '影片', 241: '印象分', 242: '猪脑子', 243: '几场', 244: '战役', 245: '拍', 246: '动不动', 247: '有人', 248: '跳出', 249: '来说', 250: '宋江', 251: '哥哥', 252: '妙计', 253: '一条', 254: '尼玛', 255: '本来', 256: '好好', 257: '屎', 258: '知道', 259: '以为', 260: '梁山', 261: '一', 262: '帮子', 263: '爷们儿', 264: '脑残', 265: '弱智', 266: '计', 267: '敢', 268: '称', 269: '怎么着', 270: '人才辈出', 271: '特技', 272: '花', 273: '没关系', 274: '可以', 275: '忍', 276: '剪辑', 277: '东倒西歪', 278: '三观', 279: '坑爹', 280: '口音', 281: '陈坤', 282: '油腻腻', 283: '油头', 284: '还是', 285: '但是', 286: '志玲', 287: '姐姐', 288: '胸', 289: '真的', 290: '第一次', 291: '看', 292: '很小', 293: '没见', 294: '过', 295: '露骨', 296: '片子', 297: '当', 298: '黄片', 299: '后来', 300: '来', 301: '英国', 302: '之后', 303: '又', 304: '一遍', 305: '没什么', 306: '意思', 307: '萨', 308: '朗斯', 309: '通', 310: '后背', 311: '挺', 312: '肥肉', 313: '现在', 314: '越开', 315: '她', 316: '顺眼', 317: '大妈', 318: '谁', 319: '赵氏', 320: '孤儿', 321: '怎么', 322: '那么', 323: '拧', 324: '巴', 325: '想来想去', 326: '陈凯歌', 327: '通过', 328: '扭曲', 329: '青少年', 330: '心理', 331: '制造', 332: '人间', 333: '悲剧', 334: '叙事', 335: '模式', 336: '先是', 337: '一个', 338: '馒头', 339: '引发', 340: '血案', 341: '这次', 342: '少年', 343: '爹', 344: '养', 345: '教', 346: '养父', 347: '唆使', 348: '下', 349: '为了', 350: '生父', 351: '报仇', 352: '杀', 353: '教父', 354: '这是', 355: '哪门子', 356: '仁义', 357: '礼智信', 358: '赞美', 359: '一下', 360: '棒子', 361: '大片', 362: '勇气', 363: '志向', 364: '简单', 365: '模式化', 366: '听到', 367: '金', 368: '研究员', 369: '创造', 370: '怪物', 371: '告诉', 372: '别人', 373: '忍不住', 374: '想吐槽', ...
# w2Vec.shape:  (54848, 50)
# train_array.shape (19998, 65)
# test_array.shape (369, 65)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score
import joblib

# 创建SVM模型
svm_model = SVC(C=1.0, kernel='rbf')

# 执行交叉验证
scores = cross_val_score(svm_model, train_array, train_lable, cv=5)

# 输出每次交叉验证的准确率
print("Cross-validation scores:", scores)

# 输出平均准确率
print("Average accuracy:", scores.mean())

# 在整个训练集上重新训练模型
svm_model.fit(train_array, train_lable)

# 保存模型
joblib.dump(svm_model, 'SVM_model.pkl')

# 在测试集上进行预测
test_pred = svm_model.predict(test_array)

# 计算预测准确率和f1值
accuracy = accuracy_score(test_lable, test_pred)
f1 = f1_score(test_lable, test_pred, average='micro')

print(f"Test accuracy: {accuracy}")
print(f"Test f1: {f1}")
# Out:
# Cross-validation scores: [0.79175    0.8465     0.84525    0.71567892 0.62565641]
# Average accuracy: 0.7649670667666916
# Test accuracy: 0.5745257452574526
# Test f1: 0.5745257452574526
